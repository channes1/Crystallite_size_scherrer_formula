# %%
# !pip install powerxrd

import powerxrd as xrd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = xrd.Data('zno-2.xy').importfile()

plt.plot(*data)
plt.show()
    
data = xrd.Data('zno-2.xy').importfile()
chart = xrd.Chart(*data)

chart.SchPeak(xrange=[33,35],verbose=True,show=True)
#chart.allpeaks()

plt.xlabel('2 $\\theta$')
plt.title('Scherrer width calculation')
plt.show()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# -Gaussian fit results-
# y-shift 0.3794739426895733
# amplitude 0.04036752404654072
# mean 34.43118550611218
# sigma 0.2012233200396772
# covariance matrix
# [[ 0.00024764 -0.00043176  0.00110057 -0.00137203]
#  [-0.00043176  0.00167502 -0.00685595  0.00608486]
#  [ 0.00110057 -0.00685595  0.03298007 -0.02564467]
#  [-0.00137203  0.00608486 -0.02564467  0.02291861]]
#
# SchPeak: Scherrer width calc. for peak in range of [33,35]
#
# FWHM == sigma*2*sqrt(2*ln(2)): 0.4738447075571098 degrees
# K (shape factor): 0.9
# K-alpha: 0.15406 nm
# max 2-theta: 34.46793644241393 degrees
#
# SCHERRER WIDTH: 17.553707029960773 nm
